# %%
import matplotlib.pyplot as plt




# TÜFE (Aylık % Değişim)
plt.plot(
    
    # alttaki değerler
    [
'Ocak (2021)',
'Şubat (2021)',
'Mart (2021)',
'Nisan (2021)',
'Mayıs (2021)',
'Haziran (2021)',
'Temmuz (2021)',
'Agustos (2021)',
'Eylül (2021)',
'Ekim (2021)',
'Kasım (2021)',
'Aralık (2021)',
'Ocak (2022)',
'Şubat (2022)'
    ], 
    
     # soldaki değerler
    [
    1.68,
    0.91,
    1.08,
    1.68,
    0.89,
    1.94,
    1.8,
    1.12,
    1.25,
    2.39,
    3.51,
    13.58,
    11.1,
    4.81

] ,label='TÜFE', linewidth=3)


#######################################################################
#######################################################################

# ÜFE (Aylık % Değişim)
plt.plot(
    
    # alttaki değerler
    [
'Ocak (2021)',
'Şubat (2021)',
'Mart (2021)',
'Nisan (2021)',
'Mayıs (2021)',
'Haziran (2021)',
'Temmuz (2021)',
'Agustos (2021)',
'Eylül (2021)',
'Ekim (2021)',
'Kasım (2021)',
'Aralık (2021)',
'Ocak (2022)',
'Şubat (2022)'
    ], 
    
     # soldaki değerler
    [
    2.66,
    1.22,
    4.13,
    4.34,
    3.92,
    4.01,
    2.46,
    2.77,
    1.55,
    5.24,
    9.99,
    19.08,
    10.45,
    7.22

], label=' ÜFE ', linewidth=3)




#######################################################################
#######################################################################

# KFE  (Aylık % Değişim)
plt.plot(
    
    # alttaki değerler
    [
'Ocak (2021)',
'Şubat (2021)',
'Mart (2021)',
'Nisan (2021)',
'Mayıs (2021)',
'Haziran (2021)',
'Temmuz (2021)',
'Agustos (2021)',
'Eylül (2021)',
'Ekim (2021)',
'Kasım (2021)',
'Aralık (2021)',
'Ocak (2022)',
'Şubat (2022)'
    ], 
    
     # soldaki değerler
    [
    1.8,
    2.5,
    2.4,
    2.0,
    3.9,
    2.8,
    2.8,
    3.9,
    3.2,
    5.7,
    9.0,
    7.9,
    10.45,
    13.1

], label=' KFE  ', linewidth=3)



plt.legend()

fig = plt.gcf()
fig.set_size_inches(18,8)
plt.title('TÜFE - ÜFE - KFE\n Ocak/2021 - Şubat/2022  \n',weight='bold', size=17)
plt.xticks(rotation=-85)
plt.xlabel("Aylar", size=17)
plt.ylabel("Bir önceki aya göre oranı (%)",  size=17 )
plt.show()

# %%
# matplotlib kitaplığının içe aktarılması
import matplotlib.pyplot as plt





# alttaki değerler
y = [
'Ocak (2021)',
'Şubat (2021)',
'Mart (2021)',
'Nisan (2021)',
'Mayıs (2021)',
'Haziran (2021)',
'Temmuz (2021)',
'Agustos (2021)',
'Eylül (2021)',
'Ekim (2021)',
'Kasım (2021)',
'Aralık (2021)',
'Ocak (2022)',
'Şubat (2022)'
]


# soldaki değerler
x = [  
17,
17,
19,
19,
19,
19,
19,
19,
18,
16,
15,
14,
14,
14   
]


# Grafik özelleştir...
plt.bar(y, x, width= 0.6, align='center',color='cyan', edgecolor = 'black')




#plt.legend()

fig = plt.gcf()
fig.set_size_inches(18,8)
plt.title('Faiz Oranı\n Ocak/2021 - Şubat/2022  \n',weight='bold', size=17)
plt.xticks(rotation=-85)
plt.xlabel("Aylar", size=17)
plt.ylabel("TCMB Faiz oranı (%)",  size=17 )
plt.show()

# %%
import matplotlib.pyplot as plt




# Dolar kuru
plt.plot(
    
    # altaki değerler
    [
'Ocak (2021)',
'Şubat (2021)',
'Mart (2021)',
'Nisan (2021)',
'Mayıs (2021)',
'Haziran (2021)',
'Temmuz (2021)',
'Agustos (2021)',
'Eylül (2021)',
'Ekim (2021)',
'Kasım (2021)',
'Aralık (2021)',
'Ocak (2022)',
'Şubat (2022)'
    ], 
    
     # soldaki değerler. ayın 15'i (14 - 16) 
    [
    7.3582,
    6.994,
    7.5329,
    8.0117,
    8.4582,
    8.5567,
    8.5663,
    8.4542,
    8.4274,
    9.2688,
    10.0527,
    14.8055,
    13.5261,
    13.6014

] ,label='Dolar', linewidth=4)



plt.legend()

fig = plt.gcf()
fig.set_size_inches(18,8)
plt.title('Dolar Kuru\n Ocak/2021 - Şubat/2022  \n',weight='bold', size=17)
plt.xticks(rotation=-85)
plt.xlabel("Aylar", size=17)
plt.ylabel("Dolar Kuru (₺)",  size=17 )
plt.show()
